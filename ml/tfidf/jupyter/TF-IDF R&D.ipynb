# %%
import numpy as np
np.set_printoptions(linewidth=200)
import pandas as pd
pd.set_option('display.width', 250)

from sklearn.feature_extraction.text import CountVectorizer
import re

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from tqdm import tqdm
import itertools
from sklearn.feature_extraction.text import TfidfTransformer

import pickle
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/davenovelli/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# read json into a dataframe
df_idf = pd.read_csv('./data/text_df.csv')

# print schema
print("Schema:\n", df_idf.dtypes)
print("\nNumber of articles, columns=", df_idf.shape)
# Out:
# Schema:
#  article_id       int64
# publisher       object
# url             object
# createdAt       object
# title           object
# subtitle        object
# text_content    object
# dtype: object
#
# Number of articles, columns= (58971, 7)

# %%
df_idf.publisher.unique()
# Out:
# array(['surfline.com', 'theinertia', 'surfer.com', 'magicseaweed.com', 'surfd.com', 'John John Florence', 'Kai Lenny', 'The Surfers Journal', 'Nathan Florence', 'Koa Rothman', 'FatSand Films',
#        'SURFER', 'World Surf League', 'Los Angeles Times', 'itsnicethat.com', 'DAN PALERMO', 'Nitya Nair', 'swellinfo', 'stabmag'], dtype=object)

# %%
# ARTICLE_COUNT = 500

def pre_process(text):    
#     print(text)
    # Manual replacements to avoid wiping out certain keywords
    text = text.replace('J.O.B', 'JOB')
    
    # lowercase
    text = text.lower()
    
    #remove tags
    text = re.sub("", "", text)
    
    # remove special characters and digits
    text = re.sub("(\\d|\\W)+", " ", text)
    
    return text

df_idf = (
    df_idf
    .query('text_content.notna() & text_content.str.len() > 1000')
    .assign(text=lambda df: df.title.fillna('') + ' ' + df.subtitle.fillna('') + ' ' + df.text_content)
    .assign(text=lambda df: df.text.str.strip().apply(pre_process))
)

df_idf
# Out:
#        article_id     publisher                                                url            createdAt                                              title                                           subtitle  \
# 0           63577  surfline.com  https://www.surfline.com/surf-news/j-o-b-soft-...  2021-05-11 23:23:43                             J.O.B. Has a Soft Side  It’s called the Red Bull Foam Wreckers, and it...
# 1           63575  surfline.com  https://www.surfline.com/surf-news/wave-day-ma...  2021-05-11 23:23:42  Wave of the Day: Matahi Drollett, Teahupoo, Ma...  Tahitian local sticks late drop and gets spit ...
# 2           63576  surfline.com  https://www.surfline.com/surf-news/two-new-edi...  2021-05-11 23:23:42  Two New Edits: Morocco is a Dredging, Right Tu...  Ramzi Boukhiam and Natxo Gonzalez just dropped...
# 3           63574    theinertia  https://www.theinertia.com/surf/14-year-old-su...  2021-05-11 22:14:38  14-Year-Old Surfer Bitten by Shark Has Attitud...                                                NaN
# 4           63573    theinertia  https://www.theinertia.com/surf/pro-surfer-los...  2021-05-11 22:14:31  Pro Surfer Loses Sponsor After Session Without...                                                NaN
# ...           ...           ...                                                ...                  ...                                                ...                                                ...
# 58966       23560    theinertia  https://www.theinertia.com/travel/surfing-cent...  2010-12-13 07:23:41                              In Search of Libertad                                                NaN
# 58967       23561    theinertia  https://www.theinertia.com/travel/scotland-isl...  2010-12-09 07:23:41                                        Whisky Wins                                                NaN
# 58968       23562    theinertia  https://www.theinertia.com/travel/inhotim-a-mu...  2010-11-17 07:23:41                 Inhotim: A Museum Unlike Any Other                                                NaN
# 58969       23563    theinertia  https://www.theinertia.com/travel/under-a-fata...  2010-11-13 07:24:03          Under a Fatal Sun, Pt. 6: New South Wales                                                NaN
# 58970       23564    theinertia  https://www.theinertia.com/travel/australia-vs...  2010-10-07 06:24:03                 Australia vs. America in 426 Words                                                NaN
#
#                                             text_content                                               text
# 0      Few people have so deftly navigated every surf...  job has a soft side it s called the red bull f...
# 1      Vid: Tim McKenna. “Although Tahiti scored a de...  wave of the day matahi drollett teahupoo may t...
# 2      Vid: Mustaphacola and Nadir LM. From a surfing...  two new edits morocco is a dredging right tube...
# 3      Parker Blanchette was bitten by a shark at Nor...   year old surfer bitten by shark has attitude ...
# 4      Without his videographer, how would timeless l...  pro surfer loses sponsor after session without...
# ...                                                  ...                                                ...
# 58966  Two surfers enjoy (and contribute to) Nicaragu...  in search of libertad two surfers enjoy and co...
# 58967  By the time I reached the thin beach trail the...  whisky wins by the time i reached the thin bea...
# 58968  The granite stone that looks like a perfect pe...  inhotim a museum unlike any other the granite ...
# 58969  The Morning of The Earth farmhouse, circa 2000...  under a fatal sun pt new south wales the morni...
# 58970  I find it surprising that Australians tend to ...  australia vs america in words i find it surpri...
#
# [37923 rows x 8 columns]

# %%
def get_stop_words():
    """ Load stop words from NLTK and include any manually assigned words to skip """
    additional_stopwords = ['surfing']
    
    return frozenset(stopwords.words('english') + additional_stopwords)

# load a set of stop words
stopword_set = get_stop_words()

# get the text column 
docs = df_idf['text'].tolist()

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]
    
    return results

def process_results(df_idf, cv, tfidf_transformer, max_df, min_df, max_features):
    # you only needs to do this once, this is a mapping of index to 
    feature_names = cv.get_feature_names()
    
    frames = []
    for i in range(df_idf.shape[0]):
        # get the article_id
        article_id = df_idf.article_id.iloc[-i]
        
        # get the url
        url = df_idf.url.iloc[-i]

        # get the document that we want to extract keywords from
        doc = df_idf.text.iloc[-i]

        #generate tf-idf for the given document
        tf_idf_vector = tfidf_transformer.transform(cv.transform([doc]))

        #sort the tf-idf vectors by descending order of scores
        sorted_items = sort_coo(tf_idf_vector.tocoo())

        #extract only the top n; n here is 20
        keywords = extract_topn_from_vector(feature_names, sorted_items, 20)
#         print(keywords)
        
        keywords_df = (
            pd.DataFrame(keywords.items(), columns=['keyword','tfidf_weight'])
            .assign(article_id=article_id)
            .assign(url=url)
            .assign(max_df=max_df)
            .assign(min_df=min_df)
            .assign(max_features=max_features)
            .assign(rank=lambda df: df.groupby(['url']).cumcount() + 1)
        )
#         print(keywords_df)
        
        frames += [keywords_df]
    
    df = pd.concat(frames, ignore_index=True)
#     print(df)
    
    return df

# %%
# max_values = [.7, .8, .9]  #[.7, .75, .8, .85, .9]
# min_values = [.1, .05, .01, .005, .001]
# max_features = [8000, 13000, 21000]
# test_articles = df_idf.groupby('publisher').head(3).reset_index()

# params = list(itertools.product(*[max_values, min_values, max_features]))
# print(f"len(params): {len(params)}")

# params_frames = []
# for max_df, min_df, features in tqdm(params):
# #     print(f"processing options: ({max_df}{min_df}{features})")
    
#     # create a vocabulary of words, 
#     # ignore words that appear in X% of documents, 
#     # eliminate stop words
#     cv = CountVectorizer(max_df=max_df, min_df=min_df, stop_words=stopword_set, ngram_range=(1, 3), max_features=features)
#     word_count_vector = cv.fit_transform(docs)
    
#     tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
#     tfidf_transformer.fit(word_count_vector)

#     results = process_results(test_articles, cv, tfidf_transformer, max_df, min_df, features)
#     params_frames += [results]

# params_df = (
#     pd.concat(params_frames, ignore_index=True)
#     .assign(params=lambda df: df.max_features.astype(str) + '_' + df.min_df.astype(str) + '_' + df.max_df.astype(str))
# )
# params_df.to_csv('paramsdf.csv', index=False)
# print(params_df)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]
# len(params): 45
# 100%|██████████| 45/45 [1:48:34<00:00, 144.78s/it]
#                 keyword  tfidf_weight  article_id                                                url  max_df  min_df  max_features  rank           params
# 0                   fun         0.420       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     1     8000_0.1_0.7
# 1                people         0.255       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     2     8000_0.1_0.7
# 2                  surf         0.237       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     3     8000_0.1_0.7
# 3                 event         0.227       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     4     8000_0.1_0.7
# 4               contest         0.225       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     5     8000_0.1_0.7
# ...                 ...           ...         ...                                                ...     ...     ...           ...   ...              ...
# 24664         late drop         0.118       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    16  21000_0.001_0.9
# 24665         view live         0.117       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    17  21000_0.001_0.9
# 24666  clean conditions         0.116       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    18  21000_0.001_0.9
# 24667    usual suspects         0.115       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    19  21000_0.001_0.9
# 24668        first week         0.114       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    20  21000_0.001_0.9
#
# [24669 rows x 9 columns]

# %%
params_df = pd.read_csv('paramsdf.csv')

# %% [markdown]
# # Convert to a format amenable to manual scoring of keywords
#
# ### Each block of 20 rows is from the same article - 10 total articles

# %%
from functools import reduce

partials = []
for params in params_df.sort_values(['max_features', 'max_df', 'min_df']).params.unique():
    currparams = (
        params_df
        .query('params == @params')
        .filter(items=['url', 'rank', 'params', 'keyword', 'tfidf_weight'])
        .rename(columns={'keyword': f'keyword__{params}', 'tfidf_weight': f'tfidf_weight__{params}'})
        .drop('params', axis=1)
    )
#     print(currparams)
    
    partials += [currparams]

results = (
    reduce(lambda x, y: pd.merge(x, y, how='outer', on=['url', 'rank']), partials)
    .sort_values(['url', 'rank'])
    .set_index(['url', 'rank'])
)
results.columns = pd.MultiIndex.from_tuples([tuple(reversed(c.split("__"))) for c in results.columns])
results.to_csv('results.csv')
results
# Out:
#                                                         8000_0.001_0.7              8000_0.005_0.7              8000_0.01_0.7              8000_0.05_0.7              8000_0.1_0.7               ... 21000_0.001_0.9              21000_0.005_0.9  \
#                                                                keyword tfidf_weight        keyword tfidf_weight       keyword tfidf_weight       keyword tfidf_weight      keyword tfidf_weight  ...         keyword tfidf_weight         keyword
# url                                                rank                                                                                                                                          ...
# https://magicseaweed.com/news/gallery-a-surf-ex... 1           country        0.373        country        0.367       country        0.409       country        0.529        waves        0.343  ...            cuba        0.654         country
#                                                    2         caribbean        0.202      caribbean        0.199     caribbean        0.221         waves        0.231         surf        0.313  ...         country        0.250       caribbean
#                                                    3             reefs        0.183   local surfer        0.189         reefs        0.201          surf        0.211       little        0.271  ...       caribbean        0.135    local surfer
#                                                    4             waves        0.163          reefs        0.180         waves        0.179          area        0.189        local        0.270  ...    local surfer        0.128           reefs
#                                                    5              surf        0.149          waves        0.160          surf        0.163        little        0.183          old        0.221  ...           reefs        0.123           waves
# ...                                                                ...          ...            ...          ...           ...          ...           ...          ...          ...          ...  ...             ...          ...             ...
# https://www.youtube.com/watch?v=xzLowIj-DuA        16            champ        0.178          champ        0.178        series        0.177           NaN          NaN          NaN          NaN  ...            wins        0.173           champ
#                                                    17          massive        0.170        massive        0.170           six        0.174           NaN          NaN          NaN          NaN  ...           champ        0.169         massive
#                                                    18            sport        0.157          sport        0.157         north        0.145           NaN          NaN          NaN          NaN  ...         massive        0.161           sport
#                                                    19           series        0.157         series        0.157          part        0.143           NaN          NaN          NaN          NaN  ...           sport        0.149          series
#                                                    20              six        0.155            six        0.155         swell        0.140           NaN          NaN          NaN          NaN  ...          series        0.149             six
#
#                                                                      21000_0.01_0.9              21000_0.05_0.9              21000_0.1_0.9
#                                                         tfidf_weight        keyword tfidf_weight        keyword tfidf_weight       keyword tfidf_weight
# url                                                rank
# https://magicseaweed.com/news/gallery-a-surf-ex... 1           0.367        country        0.409        country        0.529         waves        0.343
#                                                    2           0.199      caribbean        0.221          waves        0.231          surf        0.313
#                                                    3           0.189          reefs        0.201           surf        0.211        little        0.271
#                                                    4           0.180          waves        0.179           area        0.189         local        0.270
#                                                    5           0.160           surf        0.163         little        0.183           old        0.221
# ...                                                              ...            ...          ...            ...          ...           ...          ...
# https://www.youtube.com/watch?v=xzLowIj-DuA        16          0.178         series        0.177            NaN          NaN           NaN          NaN
#                                                    17          0.170            six        0.174            NaN          NaN           NaN          NaN
#                                                    18          0.157          north        0.145            NaN          NaN           NaN          NaN
#                                                    19          0.157           part        0.143            NaN          NaN           NaN          NaN
#                                                    20          0.155          swell        0.140            NaN          NaN           NaN          NaN
#
# [643 rows x 90 columns]

# %%
adf = (
    reduce(lambda x, y: pd.merge(x, y, how='outer', on=['url', 'rank']), partials)
    .sort_values(['url', 'rank'])
)
cols = [c for c in adf.columns.values if 'keyword__' in c]

urls = adf.url.unique()
seriess = []
for url in urls:
    urldf = (
        adf.query('url == @url')
        .filter(items=cols)
    )
#     print(urldf)
    
    url_keywords = pd.Series(pd.unique(urldf[cols].values.ravel('K'))).dropna().sort_values()
    print(f"{url}:\n{url_keywords.tolist()}\n")
    seriess += [url_keywords]
    
keywords_df = pd.concat(seriess, axis=1, keys=urls)
keywords_df.to_csv('urlkeywords.csv', index=False)
keywords_df
# Out:
# https://magicseaweed.com/news/gallery-a-surf-expedition-through-untouched-cuba/12380/:
# ['area', 'average', 'boards', 'boulders', 'caribbean', 'city', 'coastline', 'country', 'cuba', 'different', 'difficult', 'expedition', 'find', 'frank', 'fun', 'get', 'go', 'gonzalez', 'good', 'head', 'la', 'little', 'local', 'local surfer', 'locals', 'many', 'mentawais', 'near', 'old', 'one best surfers', 'people', 'quality', 'quality waves', 'realise', 'really', 'reefs', 'something different', 'spot', 'spots', 'surf', 'surfer', 'take', 'think', 'trip', 'waves']
#
# https://magicseaweed.com/news/surfing-the-alps-how-the-landlocked-swiss-surf-team-are-raising-their-game/12377/:
# ['air', 'air game', 'air section', 'also', 'bay', 'coach', 'country', 'culture', 'element', 'everything', 'facility', 'game', 'games', 'improvement', 'isa', 'isa world', 'isa world games', 'landlocked', 'like', 'love', 'might', 'much', 'national', 'people', 'placed', 'pool', 'rachel', 'rd', 'right', 'river', 'said', 'section', 'sessions', 'snowboard', 'sports', 'st', 'surf', 'swiss', 'switzerland', 'team', 'time', 'times', 'training', 'wave', 'waves', 'wins', 'world', 'world games', 'would', 'years']
#
# https://magicseaweed.com/news/the-miraculous-circumstances-that-makes-mundaka-pump/12382/:
# ['almost', 'along', 'angle', 'autumn', 'bar', 'best', 'big', 'break', 'edge', 'end', 'factors', 'first', 'flow', 'half', 'incoming', 'large', 'length', 'long', 'many', 'might', 'mundaka', 'must', 'offshore', 'outer', 'right', 'river', 'sandbar', 'scale', 'season', 'sediment', 'shape', 'small', 'spots', 'storms', 'summer', 'swell', 'swells', 'throughout', 'tidal', 'tide', 'time', 'wave', 'waves', 'way', 'wind', 'winter', 'year']
#
# https://stabmag.com/news/finally-a-sensical-and-supportive-womens-big-wave-event:
# ['ago', 'along', 'already', 'bay', 'big', 'big wave', 'big wave event', 'big wave world', 'canceled', 'career', 'competitive', 'conditions', 'critics', 'danger', 'despite', 'discipline', 'dollars', 'emi', 'emi erickson', 'erickson', 'established', 'even', 'event', 'event even', 'every winter', 'fails', 'five', 'give', 'hawaii', 'heard', 'jobs', 'last years', 'losses', 'love', 'many surfers', 'news', 'nothing', 'ocean', 'one', 'opinions', 'passionate', 'passions', 'pressure', 'professional', 'professional career', 'rather', 'reduced', 'represent', 'running', 'says', 'spots', 'start', 'supportive', 'surprising', 'sustained', 'swells', 'thinks', 'tour', 'wave', 'wave conditions', 'wave event', 'wave world', 'wave world tour', 'waves around', 'waves around world', 'winter', 'women big', 'women big wave', 'world', 'world tour', 'xl', 'year ago']
#
# https://stabmag.com/news/leaked-wsl-memo-we-have-confidence-in-the-resumption-of-the-pipe-masters:
# ['allegedly', 'arrives', 'assuming', 'case', 'catch', 'coming', 'coming days', 'competition', 'confidence', 'contact', 'contained', 'curious', 'days', 'dispatch', 'end', 'event', 'forecast', 'group', 'happen', 'hawaii', 'including', 'internal', 'know', 'last', 'leaked', 'let', 'light', 'looking', 'masters', 'matter', 'new', 'next', 'officials', 'open', 'original', 'pipe', 'pipe masters', 'pipeline', 'positive', 'pretty', 'pro', 'protocols', 'since', 'spread', 'state', 'surfers', 'swell', 'today', 'towards', 'us', 'virus', 'well', 'wsl']
#
# https://stabmag.com/news/wsl-suspends-pipe-masters-after-staffers-contract-coronavirus:
# ['anyone', 'athletes', 'believe', 'billabong', 'billabong pipe', 'billabong pipe masters', 'ceo', 'cleared', 'closely', 'comes', 'community', 'competition', 'confirmed', 'continue', 'contract', 'coronavirus', 'covid', 'decided', 'department', 'determine', 'else', 'erik', 'execute', 'exposed', 'forward', 'goes', 'hawaii', 'hydro', 'implemented', 'including', 'info', 'logan', 'masters', 'news', 'oh', 'oh god', 'part', 'pipe', 'pipe masters', 'positive', 'protocols', 'result', 'returned', 'safety', 'share', 'staff', 'state', 'story', 'surrounding', 'tests', 'update', 'within', 'working', 'wsl', 'wsl ceo']
#
# https://surfd.com/2021/03/10-of-the-best-surf-hats/:
# ['also', 'away', 'back', 'best', 'better', 'billabong', 'bucket', 'buy', 'cancer', 'cap', 'chin', 'dakine', 'designed', 'fabric', 'fcs', 'features', 'front', 'good', 'hat', 'hats', 'head', 'keep', 'less', 'little', 'made', 'many', 'materials', 'may', 'means', 'mesh', 'much', 'neck', 'neill', 'neoprene', 'nylon', 'paddling', 'patagonia', 'peak', 'polyester', 'protect', 'protection', 'quick', 'recycled', 'rip', 'side', 'simple', 'skin', 'soft', 'strap', 'strong', 'style', 'sun', 'super', 'surf', 'surfers', 'use', 'uv', 'vision', 'water', 'wave', 'waves', 'wear', 'yet']
#
# https://surfd.com/2021/03/a-collection-of-the-best-surf-documentaries-ever-made/:
# ['along', 'andy', 'back', 'best', 'beyond', 'big', 'boys', 'code', 'code red', 'collective', 'dana', 'documentaries', 'documentary', 'early', 'ever', 'ever made', 'every', 'feature', 'film', 'first', 'fish', 'frank', 'generation', 'get', 'giants', 'irons', 'jordy', 'kissed', 'kissed god', 'laird hamilton', 'let', 'life', 'liquid', 'modern', 'modern collective', 'momentum', 'momentum generation', 'moore', 'one', 'pretty', 'riding', 'sea', 'seen', 'south', 'step', 'surf', 'surfer', 'watch', 'way', 'world', 'worlds']
#
# https://surfd.com/2021/04/lip-sunglasses-review/:
# ['anti', 'better', 'com', 'design', 'enough', 'excellent', 'eye', 'find', 'get', 'glare', 'glasses', 'hard', 'however', 'leash', 'least', 'lens', 'lenses', 'light', 'lip', 'longer', 'makes', 'may', 'means', 'model', 'need', 'one', 'perfect', 'performance', 'quality', 'quickly', 'range', 'review', 'ride', 'safety', 'say', 'see', 'strong', 'sunglasses', 'surf', 'system', 'type', 'typhoon', 'unique', 'us', 'use', 'vision', 'water', 'waves', 'wear', 'windsurfing']
#
# https://www.itsnicethat.com/articles/afrosurf-publication-180321:
# ['across', 'africa', 'african', 'brand', 'compilation', 'continent', 'culture', 'one', 'page', 'produced', 'publication', 'sees', 'stories', 'surfers']
#
# https://www.latimes.com/lifestyle/story/2021-03-26/manhattan-beach-racial-slurs-make-black-surfers-activists:
# ['activists', 'beach', 'black', 'brick', 'called', 'changed', 'getting', 'justin', 'make', 'manhattan', 'manhattan beach', 'racial', 'role', 'sport', 'surfers', 'view']
#
# https://www.surfer.com/magazine/cbd-for-athletes-entourage-effect-for-the-win:
# ['able', 'aid', 'along', 'also', 'always', 'athletes', 'athletic', 'bay', 'best', 'body', 'brain', 'cbd', 'comes', 'could', 'early', 'effect', 'entourage', 'experience', 'focus', 'full', 'help', 'human body', 'including', 'inflammation', 'interaction', 'known', 'lead', 'many', 'mind', 'natural', 'naturally', 'often', 'pain', 'people', 'performance', 'process', 'product', 'products', 'put', 'quality', 'recovery', 'relief', 'results', 'spectrum', 'sport', 'sports', 'stress', 'system', 'taken', 'taking', 'things', 'thought', 'training', 'tribe', 'turn', 'turning', 'well']
#
# https://www.surfer.com/videos/tatiana-weston-webb-and-filipe-toledo-win-margaret-river-pro:
# ['always', 'amazing', 'aus', 'best', 'best result', 'break', 'bronte', 'career', 'champion', 'day', 'event', 'filipe', 'filipe toledo', 'final', 'finals', 'finals day', 'find', 'first', 'first time', 'gilmore', 'heat', 'macaulay', 'main', 'main break', 'margaret', 'margaret river', 'one', 'rankings', 'result', 'river', 'said', 'season', 'second', 'smith', 'spot', 'start', 'stoked', 'tatiana', 'tatiana weston', 'tatiana weston webb', 'th', 'time', 'today', 'toledo', 'victory', 'webb', 'weston', 'weston webb', 'win', 'world', 'wsl']
#
# https://www.surfer.com/videos/tosh-tudor-has-style-imbedded-in-his-dna:
# ['across', 'apple', 'around', 'beautiful', 'breaking', 'breaking wave', 'click', 'click play', 'comes', 'cutbacks', 'dna', 'edit', 'enjoy', 'esque', 'face', 'face wave', 'fall', 'family', 'far', 'filmed', 'fish', 'gliding', 'grab', 'graceful', 'gun', 'hawaii', 'head', 'hit', 'iconic', 'image', 'joel', 'joel tudor', 'lanky', 'long', 'make', 'make want', 'mostly', 'nearest', 'newest', 'past', 'play', 'retro', 'shapes', 'spitting', 'style', 'tosh', 'tree', 'tudor', 'vans', 'want', 'watch', 'wave', 'way', 'way around', 'winter', 'young']
#
# https://www.surfersjournal.com/editorial/excerpt-the-night-and-the-iguana/:
# ['designs', 'escaping', 'excerpt', 'going', 'island', 'journal', 'night', 'pay', 'prison', 'surfers']
#
# https://www.surfline.com/surf-news/j-o-b-soft-side/119874:
# ['back', 'brien', 'bull', 'catch', 'catch surf', 'contest', 'cool', 'event', 'events', 'first', 'foam', 'fun', 'hard', 'idea', 'jamie', 'jamie brien', 'job', 'kids', 'laird', 'least', 'like', 'mean', 'people', 'red', 'red bull', 'show', 'soft', 'soft top', 'surf', 'surfline', 'think', 'times', 'together', 'top', 'want', 'watch', 'win', 'world']
#
# https://www.surfline.com/surf-news/two-new-edits-morocco-dredging-right-tube-paradise/119863:
# ['actually', 'anchor', 'anchor point', 'ate', 'bank', 'boukhiam', 'diamond', 'dredging', 'edits', 'energy', 'fast', 'forecast', 'forged', 'go really', 'gods', 'going', 'gonzalez', 'hard', 'home', 'jon', 'like', 'lit', 'live', 'longboards', 'lot', 'mellow', 'morocco', 'much time', 'natxo', 'natxo gonzalez', 'one', 'one biggest', 'pace', 'past', 'perfect', 'ramzi', 'ramzi boukhiam', 'read', 'really', 'really hard', 'rights', 'rippers', 'sand', 'separate', 'shit', 'shortboards', 'since', 'slower', 'spent', 'sure', 'surfed', 'surfer one', 'surfers like', 'swell', 'swells', 'time', 'time like', 'times', 'trying', 'trying figure', 'tube', 'two', 'two new', 'two separate', 'user friendly', 'vert', 'vid', 'view', 'view live', 'wave', 'winter']
#
# https://www.surfline.com/surf-news/wave-day-matahi-drollett-teahupoo-may-10th/119898:
# ['although', 'ask', 'bottom', 'bottom wave', 'cam', 'clean', 'clean conditions', 'conditions', 'couple', 'couple months', 'crowd', 'day', 'drollet', 'drop', 'dust', 'eight', 'eight foot', 'end', 'end road', 'first week', 'foot', 'foot plus', 'glassy', 'got barreled', 'guns', 'head', 'hour', 'keg', 'kevin', 'last', 'last couple', 'last years', 'late drop', 'live', 'longtime', 'massive', 'matahi', 'matahi drollet', 'may', 'may th', 'morning', 'perfect', 'plus', 'road', 'run', 'scored', 'season', 'settled', 'small', 'south', 'south swell', 'spit', 'start', 'start season', 'sticks', 'surf perfect', 'suspects', 'tahiti', 'tahitian', 'teahupoo', 'th', 'tim', 'traded', 'unusually', 'usual suspects', 'vid', 'view', 'view live', 'wave', 'wave got', 'week', 'went']
#
# https://www.swellinfo.com/video/mal-y-bueno-ft-davey-stiles-surfing:
# ['amazingly', 'california', 'davey', 'eventually', 'first', 'ft', 'kinds', 'lockdown', 'malibu', 'quarantine', 'south', 'south swell', 'swell', 'uncrowded', 'videos']
#
# https://www.theinertia.com/surf/14-year-old-surfer-bitten-by-shark-has-attitude-worth-emulating:
# ['actually', 'apex', 'area', 'attitude', 'authorities', 'big deal', 'bit', 'bitten', 'board', 'call', 'call home', 'calmly', 'chill', 'corps', 'could happen', 'couple', 'cracking', 'darn', 'definitely', 'eighth', 'fact', 'family', 'felt', 'flesh', 'going need', 'happen', 'home turf', 'hopping', 'incident', 'jaw', 'jumped', 'keep', 'kind', 'knew', 'knew could', 'knows', 'leg', 'lifeguards', 'local', 'may', 'media', 'mind', 'miracle', 'mom', 'need', 'north', 'ocean', 'old surfer', 'parker', 'places', 'predator', 'punch', 'ride', 'ride waves', 'said', 'scared', 'seeing', 'shark', 'sharks', 'shore', 'sink', 'stitches', 'teeth', 'though', 'told', 'turf', 'wait', 'wave', 'worried', 'worth', 'year old', 'year old surfer']
#
# https://www.theinertia.com/surf/look-how-good-impossibles-was-on-may-10th:
# ['back', 'back back', 'basically', 'bigger', 'blow', 'bukit', 'came', 'came together', 'class waves', 'course', 'dry', 'east', 'empty', 'everything', 'fickle', 'files', 'found', 'good', 'guys', 'hander', 'hit', 'hits', 'july august', 'late', 'lining', 'look', 'look good', 'lot', 'low', 'low tide', 'may', 'may th', 'mean', 'months', 'pandemic', 'peninsula', 'positively', 'raw', 'right hander', 'season', 'sets', 'silver', 'silver lining', 'solid', 'solid swell', 'spot', 'started', 'surf', 'swell', 'swell water', 'swells', 'terrible', 'th', 'though', 'time even', 'together', 'tourism', 'whole', 'whole lot', 'winds', 'wise', 'work', 'working', 'world class', 'world class waves', 'youtube']
#
# https://www.theinertia.com/surf/pro-surfer-loses-sponsor-after-session-without-videographer:
# ['anonymous', 'beach', 'bee', 'behind', 'brand', 'catching waves', 'could', 'even', 'everything', 'expressed', 'eye', 'fact', 'fierce', 'get', 'idea', 'least', 'liability', 'like', 'lost', 'media', 'narrative', 'one', 'others', 'photo', 'plugs', 'professional', 'professional surfers', 'rep', 'session', 'show', 'social', 'social media', 'sponsor', 'spot', 'started', 'surf', 'surfer', 'texted', 'timeless', 'told', 'utah', 'videographer', 'week', 'without', 'worst', 'would']
#
# https://www.youtube.com/watch?v=57DlpdQUdE4:
# ['angeles', 'begins', 'billy', 'billy kemper', 'california', 'chapter', 'emergency', 'family', 'finally', 'flight', 'harrowing', 'kemper', 'long', 'long road', 'los', 'los angeles', 'mile', 'morocco', 'recovery', 'road', 'touches', 'trip']
#
# https://www.youtube.com/watch?v=I_GZJ0MewXM:
# ['ago', 'almost', 'became', 'capture', 'could', 'decades', 'decades ago', 'enough', 'extreme', 'friends', 'getting', 'goal', 'great', 'great lakes', 'keeping', 'lakes', 'point', 'started', 'started getting', 'youtube']
#
# https://www.youtube.com/watch?v=JrrdFeGCjmE:
# ['always', 'always wanted', 'break', 'channel', 'due', 'first', 'learn', 'learn surf', 'something', 'surf', 'thought', 'video', 'wanted', 'warned', 'week', 'welcome', 'youtube', 'youtube channel']
#
# https://www.youtube.com/watch?v=NAjHmCnS3-o:
# ['antonio', 'beautiful', 'beautiful thing', 'best', 'best right', 'describes', 'ever', 'ever seen', 'fickle', 'filmmaker', 'life', 'magazine', 'mysto', 'perfection', 'point', 'right', 'right point', 'righthand', 'seen', 'si', 'surfer', 'surfer magazine', 'thing', 'thing ever', 'wish', 'world', 'youtube']
#
# https://www.youtube.com/watch?v=RI3xeLLxHiw:
# ['com', 'dealing', 'episode', 'get', 'guys', 'guys know', 'https', 'injury', 'know', 'livin', 'neck', 'recovery', 'road', 'spine', 'surgery', 'years']
#
# https://www.youtube.com/watch?v=V8UYsPRzjSA:
# ['ben', 'day', 'featuring', 'find', 'footage', 'india', 'lot', 'love', 'session', 'shooting', 'soul', 'stacked', 'surf', 'surf team', 'team', 'water', 'water day', 'youtube']
#
# https://www.youtube.com/watch?v=VoMEDcXBzik:
# ['com', 'firing', 'get', 'going', 'https', 'john', 'john john', 'koa', 'like', 'livin', 'pipeline', 'point', 'pounded', 'rocky', 'rocky point', 'subscribe', 'waves', 'waves going', 'youtube']
#
# https://www.youtube.com/watch?v=WWBSP__lYjkhttps://www.youtube.com/watch?v=WWBSP__lYjk:
# ['big', 'big wave', 'caught', 'caught inside', 'challenge', 'competition', 'escondido', 'first', 'first big', 'foot', 'foot wave', 'gopro', 'inside', 'mexico', 'pov', 'puerto', 'puerto escondido', 'wave', 'win']
#
# https://www.youtube.com/watch?v=XTq1gufrm18:
# ['back', 'back board', 'billy', 'billy kemper', 'board', 'chapter', 'cleared', 'get', 'get back', 'getting', 'getting ready', 'goal', 'jaws', 'kemper', 'one', 'ready', 'return', 'sets', 'sights', 'surf', 'triumphant', 'ultimate', 'ultimate goal']
#
# https://www.youtube.com/watch?v=a3djTtlH2OM:
# ['channel', 'com', 'first', 'first light', 'follow', 'follow instagram', 'help', 'help support', 'insane', 'instagram', 'legends', 'light', 'mexico', 'please', 'session', 'subscribe', 'support', 'www']
#
# https://www.youtube.com/watch?v=n3NS9bPa5qY:
# ['appearance', 'feat', 'featured', 'film', 'florence', 'home', 'january', 'john', 'john florence', 'john john', 'john john florence', 'location', 'maps', 'march', 'north', 'north shore', 'north shore oahu', 'oahu', 'order', 'shore', 'shore oahu', 'short', 'short film', 'shot', 'surfers']
#
# https://www.youtube.com/watch?v=xzLowIj-DuA:
# ['adrenaline', 'atlantic', 'big', 'big wave', 'billy', 'champ', 'chapter', 'documentary', 'episode', 'massive', 'meet', 'morocco', 'north', 'north atlantic', 'one', 'one sport', 'part', 'premiere', 'pumping', 'series', 'six', 'sport', 'swell', 'wave', 'wins', 'world']
#    https://magicseaweed.com/news/gallery-a-surf-expedition-through-untouched-cuba/12380/ https://magicseaweed.com/news/surfing-the-alps-how-the-landlocked-swiss-surf-team-are-raising-their-game/12377/  \
# 0                                             country                                                                                  team
# 1                                           caribbean                                                                              training
# 2                                               reefs                                                                              facility
# 3                                               waves                                                                                   bay
# 4                                                surf                                                                           world games
# ..                                                ...                                                                                   ...
# 67                                                NaN                                                                                   NaN
# 68                                                NaN                                                                                   NaN
# 69                                                NaN                                                                                   NaN
# 70                                                NaN                                                                                   NaN
# 71                                                NaN                                                                                   NaN
#
#    https://magicseaweed.com/news/the-miraculous-circumstances-that-makes-mundaka-pump/12382/ https://stabmag.com/news/finally-a-sensical-and-supportive-womens-big-wave-event  \
# 0                                             mundaka                                                                                  big wave
# 1                                                 bar                                                                                       big
# 2                                              swells                                                                                wave event
# 3                                             sandbar                                                                                        xl
# 4                                               waves                                                                           wave world tour
# ..                                                ...                                                                                       ...
# 67                                                NaN                                                                           wave conditions
# 68                                                NaN                                                                                event even
# 69                                                NaN                                                                              every winter
# 70                                                NaN                                                                       professional career
# 71                                                NaN                                                                        waves around world
#
#    https://stabmag.com/news/leaked-wsl-memo-we-have-confidence-in-the-resumption-of-the-pipe-masters https://stabmag.com/news/wsl-suspends-pipe-masters-after-staffers-contract-coronavirus https://surfd.com/2021/03/10-of-the-best-surf-hats/  \
# 0                                                 wsl                                                                                               wsl                                                                                    hat
# 1                                        pipe masters                                                                                             logan                                                                                   surf
# 2                                             masters                                                                                            safety                                                                             protection
# 3                                            internal                                                                                             covid                                                                                    cap
# 4                                                pipe                                                                                               ceo                                                                               features
# ..                                                ...                                                                                               ...                                                                                    ...
# 67                                                NaN                                                                                               NaN                                                                                    NaN
# 68                                                NaN                                                                                               NaN                                                                                    NaN
# 69                                                NaN                                                                                               NaN                                                                                    NaN
# 70                                                NaN                                                                                               NaN                                                                                    NaN
# 71                                                NaN                                                                                               NaN                                                                                    NaN
#
#    https://surfd.com/2021/03/a-collection-of-the-best-surf-documentaries-ever-made/ https://surfd.com/2021/04/lip-sunglasses-review/ https://www.itsnicethat.com/articles/afrosurf-publication-180321  ... https://www.youtube.com/watch?v=JrrdFeGCjmE  \
# 0                                                film                                                                     sunglasses                                            stories                ...                                     youtube
# 1                                               frank                                                                            lip                                          continent                ...                                     welcome
# 2                                                surf                                                                        typhoon                                               sees                ...                                     channel
# 3                                               jordy                                                                         lenses                                            african                ...                                         due
# 4                                                 one                                                                           lens                                           produced                ...                                       learn
# ..                                                ...                                                                            ...                                                ...                ...                                         ...
# 67                                                NaN                                                                            NaN                                                NaN                ...                                         NaN
# 68                                                NaN                                                                            NaN                                                NaN                ...                                         NaN
# 69                                                NaN                                                                            NaN                                                NaN                ...                                         NaN
# 70                                                NaN                                                                            NaN                                                NaN                ...                                         NaN
# 71                                                NaN                                                                            NaN                                                NaN                ...                                         NaN
#
#    https://www.youtube.com/watch?v=NAjHmCnS3-o https://www.youtube.com/watch?v=RI3xeLLxHiw https://www.youtube.com/watch?v=V8UYsPRzjSA https://www.youtube.com/watch?v=VoMEDcXBzik  \
# 0                                        point                                       spine                                        soul                                       rocky
# 1                                    righthand                                     surgery                                       india                                    pipeline
# 2                                   thing ever                                     dealing                                     stacked                                        john
# 3                                    describes                                        neck                                   surf team                                   subscribe
# 4                                       fickle                                    recovery                                     youtube                                       point
# ..                                         ...                                         ...                                         ...                                         ...
# 67                                         NaN                                         NaN                                         NaN                                         NaN
# 68                                         NaN                                         NaN                                         NaN                                         NaN
# 69                                         NaN                                         NaN                                         NaN                                         NaN
# 70                                         NaN                                         NaN                                         NaN                                         NaN
# 71                                         NaN                                         NaN                                         NaN                                         NaN
#
#    https://www.youtube.com/watch?v=WWBSP__lYjkhttps://www.youtube.com/watch?v=WWBSP__lYjk https://www.youtube.com/watch?v=XTq1gufrm18 https://www.youtube.com/watch?v=a3djTtlH2OM https://www.youtube.com/watch?v=n3NS9bPa5qY  \
# 0                                               gopro                                                                           billy                                   instagram                                        john
# 1                                           foot wave                                                                    billy kemper                                   subscribe                                   john john
# 2                                    puerto escondido                                                                          kemper                            follow instagram                                  short film
# 3                                           escondido                                                                            jaws                                     legends                                        feat
# 4                                              puerto                                                                            goal                                      insane                            north shore oahu
# ..                                                ...                                                                             ...                                         ...                                         ...
# 67                                                NaN                                                                             NaN                                         NaN                                         NaN
# 68                                                NaN                                                                             NaN                                         NaN                                         NaN
# 69                                                NaN                                                                             NaN                                         NaN                                         NaN
# 70                                                NaN                                                                             NaN                                         NaN                                         NaN
# 71                                                NaN                                                                             NaN                                         NaN                                         NaN
#
#    https://www.youtube.com/watch?v=xzLowIj-DuA
# 0                                     big wave
# 1                                      morocco
# 2                                   adrenaline
# 3                               north atlantic
# 4                                      chapter
# ..                                         ...
# 67                                         NaN
# 68                                         NaN
# 69                                         NaN
# 70                                         NaN
# 71                                         NaN
#
# [72 rows x 34 columns]

# %% [markdown]
# ## Read in the term scores to identify best hyperparams

# %%
keywords = (
    pd.read_csv('urlkeywords_scored_20210604.csv')
    .dropna(axis='columns', how='all').head()
)
keywords.head()
# Out:
#   https://magicseaweed.com/news/gallery-a-surf-expedition-through-untouched-cuba/12380/  Unnamed: 1 https://magicseaweed.com/news/surfing-the-alps-how-the-landlocked-swiss-surf-team-are-raising-their-game/12377/  Unnamed: 4  \
# 0                                               cuba                                            1.0                                    isa world games                                                                      1.0
# 1                                          caribbean                                            1.0                                               team                                                                      1.0
# 2                                           gonzalez                                            1.0                                           training                                                                      1.0
# 3                                              frank                                            1.0                                           facility                                                                      1.0
# 4                                       local surfer                                            1.0                                        world games                                                                      1.0
#
#   https://magicseaweed.com/news/the-miraculous-circumstances-that-makes-mundaka-pump/12382/   .2 https://stabmag.com/news/finally-a-sensical-and-supportive-womens-big-wave-event   .3  \
# 0                                            mundaka                                         1.0                                           big wave                                1.0
# 1                                             swells                                         1.0                                                big                                1.0
# 2                                            sandbar                                         1.0                                         wave event                                1.0
# 3                                              waves                                         1.0                                                 xl                                1.0
# 4                                              shape                                         1.0                                    wave world tour                                1.0
#
#   https://stabmag.com/news/leaked-wsl-memo-we-have-confidence-in-the-resumption-of-the-pipe-masters   .4  ... https://www.youtube.com/watch?v=WWBSP__lYjkhttps://www.youtube.com/watch?v=WWBSP__lYjk  Unnamed: 70  \
# 0                                                wsl                                                 1.0  ...                                      caught inside                                              1.0
# 1                                       pipe masters                                                 1.0  ...                                   puerto escondido                                              1.0
# 2                                            masters                                                 1.0  ...                                               wave                                              1.0
# 3                                               pipe                                                 1.0  ...                                             mexico                                              1.0
# 4                                          officials                                                 1.0  ...                                          escondido                                              1.0
#
#   https://www.youtube.com/watch?v=XTq1gufrm18  Unnamed: 72 https://www.youtube.com/watch?v=a3djTtlH2OM  Unnamed: 74 https://www.youtube.com/watch?v=n3NS9bPa5qY  Unnamed: 76 https://www.youtube.com/watch?v=xzLowIj-DuA  Unnamed: 78
# 0                                billy kemper          1.0                                 first light          1.0                          john john florence          1.0                                     morocco          1.0
# 1                                       billy          1.0                                      mexico          1.0                            north shore oahu          1.0                                       billy          1.0
# 2                                      kemper          1.0                                     session          1.0                                   john john          1.0                                    big wave          1.0
# 3                                        jaws          1.0                                         NaN          NaN                                    florence          1.0                                        wave          1.0
# 4                               ultimate goal          1.0                                      insane          0.0                                 north shore          1.0                                       swell          1.0
#
# [5 rows x 68 columns]

# %%
frames = []
for i in range(int(keywords.shape[1] / 2)):
    article = keywords.iloc[:, 2*i:2*i+2]
    url = article.columns.values[0]
    print(f"Article #{i}: {url}")
    
    article.columns = ['keyword', 'weight']
    article = article.assign(url=url)
    frames += [article]
    
keywords = pd.concat(frames).set_index('url').reset_index()
keywords
# Out:
# Article #0: https://magicseaweed.com/news/gallery-a-surf-expedition-through-untouched-cuba/12380/
# Article #1: https://magicseaweed.com/news/surfing-the-alps-how-the-landlocked-swiss-surf-team-are-raising-their-game/12377/
# Article #2: https://magicseaweed.com/news/the-miraculous-circumstances-that-makes-mundaka-pump/12382/
# Article #3: https://stabmag.com/news/finally-a-sensical-and-supportive-womens-big-wave-event
# Article #4: https://stabmag.com/news/leaked-wsl-memo-we-have-confidence-in-the-resumption-of-the-pipe-masters
# Article #5: https://stabmag.com/news/wsl-suspends-pipe-masters-after-staffers-contract-coronavirus
# Article #6: https://surfd.com/2021/03/10-of-the-best-surf-hats/
# Article #7: https://surfd.com/2021/03/a-collection-of-the-best-surf-documentaries-ever-made/
# Article #8: https://surfd.com/2021/04/lip-sunglasses-review/
# Article #9: https://www.itsnicethat.com/articles/afrosurf-publication-180321
# Article #10: https://www.latimes.com/lifestyle/story/2021-03-26/manhattan-beach-racial-slurs-make-black-surfers-activists
# Article #11: https://www.surfer.com/magazine/cbd-for-athletes-entourage-effect-for-the-win
# Article #12: https://www.surfer.com/videos/tatiana-weston-webb-and-filipe-toledo-win-margaret-river-pro
# Article #13: https://www.surfer.com/videos/tosh-tudor-has-style-imbedded-in-his-dna
# Article #14: https://www.surfersjournal.com/editorial/excerpt-the-night-and-the-iguana/
# Article #15: https://www.surfline.com/surf-news/j-o-b-soft-side/119874
# Article #16: https://www.surfline.com/surf-news/two-new-edits-morocco-dredging-right-tube-paradise/119863
# Article #17: https://www.surfline.com/surf-news/wave-day-matahi-drollett-teahupoo-may-10th/119898
# Article #18: https://www.swellinfo.com/video/mal-y-bueno-ft-davey-stiles-surfing
# Article #19: https://www.theinertia.com/surf/14-year-old-surfer-bitten-by-shark-has-attitude-worth-emulating
# Article #20: https://www.theinertia.com/surf/look-how-good-impossibles-was-on-may-10th
# Article #21: https://www.theinertia.com/surf/pro-surfer-loses-sponsor-after-session-without-videographer
# Article #22: https://www.youtube.com/watch?v=57DlpdQUdE4
# Article #23: https://www.youtube.com/watch?v=I_GZJ0MewXM
# Article #24: https://www.youtube.com/watch?v=JrrdFeGCjmE
# Article #25: https://www.youtube.com/watch?v=NAjHmCnS3-o
# Article #26: https://www.youtube.com/watch?v=RI3xeLLxHiw
# Article #27: https://www.youtube.com/watch?v=V8UYsPRzjSA
# Article #28: https://www.youtube.com/watch?v=VoMEDcXBzik
# Article #29: https://www.youtube.com/watch?v=WWBSP__lYjkhttps://www.youtube.com/watch?v=WWBSP__lYjk
# Article #30: https://www.youtube.com/watch?v=XTq1gufrm18
# Article #31: https://www.youtube.com/watch?v=a3djTtlH2OM
# Article #32: https://www.youtube.com/watch?v=n3NS9bPa5qY
# Article #33: https://www.youtube.com/watch?v=xzLowIj-DuA
#                                                    url       keyword  weight
# 0    https://magicseaweed.com/news/gallery-a-surf-e...          cuba     1.0
# 1    https://magicseaweed.com/news/gallery-a-surf-e...     caribbean     1.0
# 2    https://magicseaweed.com/news/gallery-a-surf-e...      gonzalez     1.0
# 3    https://magicseaweed.com/news/gallery-a-surf-e...         frank     1.0
# 4    https://magicseaweed.com/news/gallery-a-surf-e...  local surfer     1.0
# ..                                                 ...           ...     ...
# 165        https://www.youtube.com/watch?v=xzLowIj-DuA       morocco     1.0
# 166        https://www.youtube.com/watch?v=xzLowIj-DuA         billy     1.0
# 167        https://www.youtube.com/watch?v=xzLowIj-DuA      big wave     1.0
# 168        https://www.youtube.com/watch?v=xzLowIj-DuA          wave     1.0
# 169        https://www.youtube.com/watch?v=xzLowIj-DuA         swell     1.0
#
# [170 rows x 3 columns]

# %%
scored = params_df.merge(keywords, how='left', on=['url', 'keyword']).rename(columns={'combo': 'params'})
scored['weight'] = scored['weight'].fillna(0)
scored
# Out:
#                 keyword  tfidf_weight  article_id                                                url  max_df  min_df  max_features  rank           params  weight
# 0                   fun         0.420       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     1     8000_0.1_0.7     0.0
# 1                people         0.255       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     2     8000_0.1_0.7     0.0
# 2                  surf         0.237       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     3     8000_0.1_0.7     0.0
# 3                 event         0.227       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     4     8000_0.1_0.7     0.0
# 4               contest         0.225       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.100          8000     5     8000_0.1_0.7     0.0
# ...                 ...           ...         ...                                                ...     ...     ...           ...   ...              ...     ...
# 24664         late drop         0.118       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    16  21000_0.001_0.9     0.0
# 24665         view live         0.117       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    17  21000_0.001_0.9     0.0
# 24666  clean conditions         0.116       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    18  21000_0.001_0.9     0.0
# 24667    usual suspects         0.115       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    19  21000_0.001_0.9     0.0
# 24668        first week         0.114       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.9   0.001         21000    20  21000_0.001_0.9     0.0
#
# [24669 rows x 10 columns]

# %%
results = (
    scored
    .groupby(['url', 'params'])
    .weight.sum()
    .reset_index()
    .rename(columns={'weight': 'score'})
    .groupby('params')
    .sum()
    .sort_values(['score', 'params'], ascending=[False, True])
    .reset_index()
)
results
# Out:
#              params  score
# 0   21000_0.001_0.7  157.0
# 1   21000_0.001_0.8  157.0
# 2   21000_0.001_0.9  157.0
# 3   13000_0.001_0.7  151.0
# 4   13000_0.001_0.8  151.0
# 5   13000_0.001_0.9  151.0
# 6    8000_0.001_0.7  141.0
# 7    8000_0.001_0.8  141.0
# 8    8000_0.001_0.9  141.0
# 9   13000_0.005_0.7  128.0
# 10  13000_0.005_0.8  128.0
# 11  13000_0.005_0.9  128.0
# 12  21000_0.005_0.7  128.0
# 13  21000_0.005_0.8  128.0
# 14  21000_0.005_0.9  128.0
# 15   8000_0.005_0.7  128.0
# 16   8000_0.005_0.8  128.0
# 17   8000_0.005_0.9  128.0
# 18   13000_0.01_0.7   96.0
# 19   13000_0.01_0.8   96.0
# 20   13000_0.01_0.9   96.0
# 21   21000_0.01_0.7   96.0
# 22   21000_0.01_0.8   96.0
# 23   21000_0.01_0.9   96.0
# 24    8000_0.01_0.7   96.0
# 25    8000_0.01_0.8   96.0
# 26    8000_0.01_0.9   96.0
# 27   13000_0.05_0.7   40.0
# 28   13000_0.05_0.8   40.0
# 29   13000_0.05_0.9   40.0
# 30   21000_0.05_0.7   40.0
# 31   21000_0.05_0.8   40.0
# 32   21000_0.05_0.9   40.0
# 33    8000_0.05_0.7   40.0
# 34    8000_0.05_0.8   40.0
# 35    8000_0.05_0.9   40.0
# 36    13000_0.1_0.7   19.0
# 37    13000_0.1_0.8   19.0
# 38    13000_0.1_0.9   19.0
# 39    21000_0.1_0.7   19.0
# 40    21000_0.1_0.8   19.0
# 41    21000_0.1_0.9   19.0
# 42     8000_0.1_0.7   19.0
# 43     8000_0.1_0.8   19.0
# 44     8000_0.1_0.9   19.0

# %% [markdown]
# ## Found the best params, now let's use them...

# %%
params_df.tfidf_weight.sort_values(ascending=False).head(10)

params_df.query('max_df == .9 & min_df == 0.001 & max_features == 21000 & tfidf_weight > 0.5')

params_df.url.unique().shape
# Out:
# (34,)

# %%
top_params = results.iloc[0].params
print(f"Best hyperparams: {top_params}")
# Out:
# Best hyperparams: 21000_0.001_0.7

# %%
params_df[params_df.params == top_params].filter(items=['article_id', 'url', 'params', 'keyword', 'tfidf_weight', 'rank'])
# Out:
#       article_id                                                url           params           keyword  tfidf_weight  rank
# 7580       63577  https://www.surfline.com/surf-news/j-o-b-soft-...  21000_0.001_0.7          red bull         0.320     1
# 7581       63577  https://www.surfline.com/surf-news/j-o-b-soft-...  21000_0.001_0.7              bull         0.302     2
# 7582       63577  https://www.surfline.com/surf-news/j-o-b-soft-...  21000_0.001_0.7               red         0.248     3
# 7583       63577  https://www.surfline.com/surf-news/j-o-b-soft-...  21000_0.001_0.7              foam         0.225     4
# 7584       63577  https://www.surfline.com/surf-news/j-o-b-soft-...  21000_0.001_0.7             jamie         0.185     5
# ...          ...                                                ...              ...               ...           ...   ...
# 8218       63575  https://www.surfline.com/surf-news/wave-day-ma...  21000_0.001_0.7         late drop         0.118    16
# 8219       63575  https://www.surfline.com/surf-news/wave-day-ma...  21000_0.001_0.7         view live         0.117    17
# 8220       63575  https://www.surfline.com/surf-news/wave-day-ma...  21000_0.001_0.7  clean conditions         0.116    18
# 8221       63575  https://www.surfline.com/surf-news/wave-day-ma...  21000_0.001_0.7    usual suspects         0.115    19
# 8222       63575  https://www.surfline.com/surf-news/wave-day-ma...  21000_0.001_0.7        first week         0.114    20
#
# [643 rows x 6 columns]

# %%
max_features, min_df, max_df = map(float, top_params.split('_'))

# %%
# %%time

cv = CountVectorizer(stop_words=stopword_set, ngram_range=(1, 3), max_df=max_df, min_df=min_df, max_features=features)
word_count_vector = cv.fit_transform(docs)

tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(word_count_vector)

# save the CountVectorizer as a pickle
pickle.dump((cv, tfidf_transformer), open("count_vectorizer.pickle", "wb"))
# Out:
# CPU times: user 2min 43s, sys: 10.9 s, total: 2min 54s
# Wall time: 2min 58s

# %%
results = process_results(df_idf, cv, tfidf_transformer, max_df, min_df, features)
results
# Out:
#                   keyword  tfidf_weight  article_id                                                url  max_df  min_df  max_features  rank
# 0                red bull         0.320       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.001         21000     1
# 1                    bull         0.302       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.001         21000     2
# 2                     red         0.248       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.001         21000     3
# 3                    foam         0.225       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.001         21000     4
# 4                   jamie         0.185       63577  https://www.surfline.com/surf-news/j-o-b-soft-...     0.7   0.001         21000     5
# ...                   ...           ...         ...                                                ...     ...     ...           ...   ...
# 1161585         late drop         0.118       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.7   0.001         21000    16
# 1161586         view live         0.117       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.7   0.001         21000    17
# 1161587  clean conditions         0.116       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.7   0.001         21000    18
# 1161588    usual suspects         0.115       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.7   0.001         21000    19
# 1161589        first week         0.114       63575  https://www.surfline.com/surf-news/wave-day-ma...     0.7   0.001         21000    20
#
# [1161590 rows x 8 columns]

# %%
results.tfidf_weight.max()
# Out:
# 1.0

# %% [markdown]
# ### Test the pickled vectorizer...

# %%
# load pickle
vectorizer = pickle.load(open("count_vectorizer.pickel", "rb"))

test_article_id = '1234567'
test_url = 'https://yewreview.com/blog/this-is-a-test-url'
test_text = "Laird Hamilton is a badass dude. When he's not surfing the biggest waves on his foil he's making dope powder for my coffee. I love that it tastes like coconut and it's so good"
row = [(test_article_id, test_url, test_text)]

test_df = pd.DataFrame(row, columns=['article_id', 'url', 'text'])
test_df

test_vector = vectorizer.transform(test_text)
test_vector

transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(test_vector)

test_results = process_results(test_df, vectorizer, tfidf_transformer, max_df, min_df, features)
test_results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-061639b0f401> in <module>
#      10 test_df
#      11
# ---> 12 test_vector = vectorizer.transform(test_text)
#      13 test_vector
#      14
#
# ~/miniconda3/envs/dogbeach/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1246         """
#    1247         if isinstance(raw_documents, str):
# -> 1248             raise ValueError(
#    1249                 "Iterable over raw text documents expected, "
#    1250                 "string object received.")
#
# ValueError: Iterable over raw text documents expected, string object received.
